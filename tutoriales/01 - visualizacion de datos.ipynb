# %% [markdown]
# # Cuaderno 1: visualización de datos
#
# En este cuaderno vamos a importar la base de datos preparada para usar PPI, y a producir una serie de visualizaciones similares a las de reporte.

# %% [markdown]
# ## Primero importamos las librerías que usaremos

# %%
from matplotlib import pyplot as plt # para hacer gráficos
import pandas as pd # para cargar datos y manipularlos
import numpy as np # para hacer operaciones matemáticas

# %% [markdown]
# ## Ahora cargamos la base de datos con los indicadores
#
# Recordemos que los indicadores ya han sido limpiados y normalizados, por lo que sus valores están entre 0.1 y 0.9. A la par, los indicadores han sido tratados de modo que un valor a la alza siempre significa una mejora.

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/oguerrer/IPP_Colombia/main/data/modeling/indicators_sample_final.csv')

# %%
# imprimimos los datos
datos
# Out:
#         2000      2001      2002      2003      2004      2005      2006  \
# 0   0.333927  0.379325  0.428000  0.481333  0.505333  0.532000  0.507411
# 1   0.202622  0.219866  0.237333  0.260000  0.268000  0.300000  0.312356
# 2   0.240474  0.254767  0.269786  0.285567  0.302143  0.319553  0.337836
# 3   0.123750  0.129536  0.135567  0.141855  0.148408  0.155238  0.162356
# 4   0.313333  0.386727  0.436679  0.483503  0.523653  0.592000  0.570557
# ..       ...       ...       ...       ...       ...       ...       ...
# 94  0.100001  0.117307  0.137444  0.160651  0.296791  0.384352  0.415701
# 95  0.299504  0.240317  0.143079  0.320487  0.441609  0.541272  0.598352
# 96  0.100006  0.106670  0.113961  0.121924  0.130603  0.140047  0.150310
# 97  0.297409  0.340960  0.388640  0.502240  0.566880  0.366880  0.341920
# 98  0.410762  0.414516  0.418164  0.421697  0.425105  0.409063  0.455436
#
#         2007      2008      2009  ...  \
# 0   0.472886  0.462667  0.516000  ...
# 1   0.324695  0.340000  0.362667  ...
# 2   0.357032  0.377183  0.398335  ...
# 3   0.166909  0.181455  0.169818  ...
# 4   0.576113  0.572587  0.562309  ...
# ..       ...       ...       ...  ...
# 94  0.433578  0.479048  0.497353  ...
# 95  0.611005  0.688952  0.743749  ...
# 96  0.161446  0.173514  0.186576  ...
# 97  0.380448  0.444384  0.233824  ...
# 98  0.375132  0.478166  0.371863  ...
#
#                                             Indicador  Instrumental  Invertir  \
# 0          Incidencia de la Pobreza Monetaria Extrema             1         1
# 1                  Incidencia de la Pobreza Monetaria             1         1
# 2               Índice de la Pobreza Multidimensional             1         1
# 3   Porcentaje de población ocupada cotizante al s...             1         0
# 4   Porcentaje de menores de 6 meses con lactancia...             1         0
# ..                                                ...           ...       ...
# 94                                  Tasa de homicidio             1         1
# 95  Tasa de víctimas directas de homicidio y de de...             1         1
# 96                     Porcentaje de hurto a personas             1         1
# 97                    Tasa de violencia interpersonal             1         1
# 98  Exportaciones totales como porcentaje del Prod...             0         0
#
#     Meta2030  MetaODS  Monitoreo  Máximo  Mínimo  ODS  \
# 0   0.793333      1.1    0.43986    0.30    0.00    1
# 1   0.650667      1.2    0.43986    0.60    0.00    1
# 2   0.765600      1.2    0.43986    0.50    0.00    1
# 3   0.348727      1.3    0.43986    0.80    0.25    1
# 4   0.646667      2.1    0.43986    0.70    0.10    2
# ..       ...      ...        ...     ...     ...  ...
# 94  0.797600     16.1    0.43986   60.00   10.00   16
# 95  0.900000     16.1    0.43986   60.00    0.00   16
# 96  0.785714     16.1    0.43986    0.15    0.01   16
# 97  0.549248     16.1    0.43986  350.00  100.00   16
# 98  0.352308    17.11    0.43986    0.25    0.12   17
#
#                         UnidadMedida
# 0                         Porcentaje
# 1                         Porcentaje
# 2                         Porcentaje
# 3                         Porcentaje
# 4                         Porcentaje
# ..                               ...
# 94  Tasa por cada 100.000 habitantes
# 95  Tasa por cada 100.000 habitantes
# 96                        Porcentaje
# 97  Tasa por cada 100.000 habitantes
# 98                        Porcentaje
#
# [99 rows x 36 columns]

# %%
# imprimimos los nombres de las columnas
datos.columns.values
# Out:
# array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', 'Abreviatura',
#        'Descripción del Indicador', 'EstadoDeDerecho', 'Fuente',
#        'IDIndicador', 'Indicador', 'Instrumental', 'Invertir', 'Meta2030',
#        'MetaODS', 'Monitoreo', 'Máximo', 'Mínimo', 'ODS', 'UnidadMedida'],
#       dtype=object)

# %%
# imprimimos todas las abreviaturas de los indicadores
datos['Abreviatura'].values
# Out:
# array(['pobr_extr', 'pobr_mone', 'pobr_multi', 'pobl_pensi', 'lacta_bebe',
#        'desnu_menor', 'mort_desnu', 'mort_mater', 'parto_medi',
#        'contro_prena', 'mort_menor', 'mort_bebe', 'inci_tuber',
#        'mort_malar', 'mort_deng', 'mort_sida', 'mort_inten', 'mort_cardi',
#        'mort_cance', 'mort_diabe', 'mort_respi', 'mort_tumor',
#        'acci_trans', 'vacu_preva', 'vacu_trip', 'afili_socia',
#        'intox_quimi', 'irca_rural', 'irca_urban', 'sabe5_leng',
#        'sabe5_mate', 'sabe9_leng', 'sabe5_mate', 'cober_media',
#        'cober_trans', 'jardi_infan', 'cober_super', 'brech_educ',
#        'anal_mas15', 'escu_inter', 'sexo_parej', 'viole_parej',
#        'psico_parej', 'homi_muje', 'sexo_otros', 'viole_otros',
#        'casad_men18', 'muje_candi', 'fecun_adole', 'brech_ingre',
#        'muje_inter', 'acces_agua', 'agua_rural', 'agua_urban',
#        'acces_sanea', 'agua_resid', 'agua_calid', 'prod_hidri',
#        'cober_energ', 'energ_renov', 'inten_energ', 'genr_elect',
#        'creci_pibc', 'traba_forma', 'pib_fores', 'tasa_desem',
#        'joven_nini', 'trab_infa', 'riesg_labor', 'pobl_turis',
#        'viaje_trans', 'co2_manuf', 'inves_desa', 'paten_nacio',
#        'coop_invde', 'perso_inter', 'ingr_pobr', 'coef_gini',
#        'brech_pobr', 'labor_pib', 'cuant_vivi', 'cuali_vivi',
#        'resid_urban', 'resid_pelig', 'dese_elimi', 'resid_bombi',
#        'recic_solid', 'afect_even', 'mar_prote', 'tierr_prote',
#        'area_bosq', 'area_resta', 'espe_amena', 'espe_vulne', 'tasa_homi',
#        'victi_homi', 'hurto_perso', 'viole_inter', 'expor_pib'],
#       dtype=object)

# %%
# imprimimos todas las abreviaturas y sus ODS correspondientes
datos[['Abreviatura', 'ODS']].values
# Out:
# array([['pobr_extr', 1],
#        ['pobr_mone', 1],
#        ['pobr_multi', 1],
#        ['pobl_pensi', 1],
#        ['lacta_bebe', 2],
#        ['desnu_menor', 2],
#        ['mort_desnu', 2],
#        ['mort_mater', 3],
#        ['parto_medi', 3],
#        ['contro_prena', 3],
#        ['mort_menor', 3],
#        ['mort_bebe', 3],
#        ['inci_tuber', 3],
#        ['mort_malar', 3],
#        ['mort_deng', 3],
#        ['mort_sida', 3],
#        ['mort_inten', 3],
#        ['mort_cardi', 3],
#        ['mort_cance', 3],
#        ['mort_diabe', 3],
#        ['mort_respi', 3],
#        ['mort_tumor', 3],
#        ['acci_trans', 3],
#        ['vacu_preva', 3],
#        ['vacu_trip', 3],
#        ['afili_socia', 3],
#        ['intox_quimi', 3],
#        ['irca_rural', 3],
#        ['irca_urban', 3],
#        ['sabe5_leng', 4],
#        ['sabe5_mate', 4],
#        ['sabe9_leng', 4],
#        ['sabe5_mate', 4],
#        ['cober_media', 4],
#        ['cober_trans', 4],
#        ['jardi_infan', 4],
#        ['cober_super', 4],
#        ['brech_educ', 4],
#        ['anal_mas15', 4],
#        ['escu_inter', 4],
#        ['sexo_parej', 5],
#        ['viole_parej', 5],
#        ['psico_parej', 5],
#        ['homi_muje', 5],
#        ['sexo_otros', 5],
#        ['viole_otros', 5],
#        ['casad_men18', 5],
#        ['muje_candi', 5],
#        ['fecun_adole', 5],
#        ['brech_ingre', 5],
#        ['muje_inter', 5],
#        ['acces_agua', 6],
#        ['agua_rural', 6],
#        ['agua_urban', 6],
#        ['acces_sanea', 6],
#        ['agua_resid', 6],
#        ['agua_calid', 6],
#        ['prod_hidri', 6],
#        ['cober_energ', 7],
#        ['energ_renov', 7],
#        ['inten_energ', 7],
#        ['genr_elect', 7],
#        ['creci_pibc', 8],
#        ['traba_forma', 8],
#        ['pib_fores', 8],
#        ['tasa_desem', 8],
#        ['joven_nini', 8],
#        ['trab_infa', 8],
#        ['riesg_labor', 8],
#        ['pobl_turis', 8],
#        ['viaje_trans', 9],
#        ['co2_manuf', 9],
#        ['inves_desa', 9],
#        ['paten_nacio', 9],
#        ['coop_invde', 9],
#        ['perso_inter', 9],
#        ['ingr_pobr', 10],
#        ['coef_gini', 10],
#        ['brech_pobr', 10],
#        ['labor_pib', 10],
#        ['cuant_vivi', 11],
#        ['cuali_vivi', 11],
#        ['resid_urban', 11],
#        ['resid_pelig', 12],
#        ['dese_elimi', 12],
#        ['resid_bombi', 12],
#        ['recic_solid', 12],
#        ['afect_even', 13],
#        ['mar_prote', 14],
#        ['tierr_prote', 15],
#        ['area_bosq', 15],
#        ['area_resta', 15],
#        ['espe_amena', 15],
#        ['espe_vulne', 15],
#        ['tasa_homi', 16],
#        ['victi_homi', 16],
#        ['hurto_perso', 16],
#        ['viole_inter', 16],
#        ['expor_pib', 17]], dtype=object)

# %%
# creamos una lista con los años en la muestra
anios = list(range(2000, 2021))

# impriminos la lista para confirmar el periodo muestral
anios
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
# por conveniencia para extrael las series de tiempo, cramos una lista con los años en tipo hilo de caracteres
anios_c = [str(anio) for anio in anios]

# impriminos la lista para confirmar el periodo muestral
anios_c
# Out:
# ['2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %% [markdown]
# ## Graficamos series de tiempo de distintos indicadores

# %%
# gráfico de pobreza extrema
x = anios
y = datos[datos['Abreviatura']=='pobr_extr'][anios_c].values[0] # extrae la fila correspondiente a pobr_extre
plt.plot(x, y)
plt.xlabel('año')
plt.ylabel('indicador de pobreza extrema')
plt.show()

# %%
# gráfico de seguridad social
x = anios
y = datos[datos['Abreviatura']=='pobl_pensi'][anios_c].values[0] # extrae la fila correspondiente a pobr_extre
plt.plot(x, y)
plt.xlabel('año')
plt.ylabel('seguridad social')
plt.show()

# %%
# graficamos todas las series de tiempo
for index, row in datos.iterrows():
    x = anios
    y = row[anios_c]
    plt.plot(x, y)
plt.xlabel('año')
plt.ylabel('nivel del indicador')
plt.show()

# %%
# cargamos datos sobre los colores de los ODS
colores = pd.read_csv('https://raw.githubusercontent.com/oguerrer/IPP_Colombia/main/data/misc/sdg_colors.txt', header=None)
colores_ods = dict(zip(colores.index+1, colores.values.flatten()))

# imprimimos la lista de colores
colores_ods
# Out:
# {1: '#E5243B',
#  2: '#DDA63A',
#  3: '#4C9F38',
#  4: '#C5192D',
#  5: '#FF3A21',
#  6: '#26BDE2',
#  7: '#FCC30B',
#  8: '#A21942',
#  9: '#FD6925',
#  10: '#DD1367',
#  11: '#FD9D24',
#  12: '#BF8B2E',
#  13: '#3F7E44',
#  14: '#0A97D9',
#  15: '#56C02B',
#  16: '#00689D',
#  17: '#19486A'}

# %%
# coloreamos de acuerdo a los ODS
for index, row in datos.iterrows():
    x = anios
    y = row[anios_c]
    ods = row['ODS']
    plt.plot(x, y, color=colores_ods[ods])
plt.xlabel('año')
plt.ylabel('nivel del indicador')
plt.show()

# %% [markdown]
# ## Manipulamos los datos para hacer gráficos más intuitivos

# %%
# Promediamos las series a nivel ODS y las graficamos
datos_promedio_ods = datos.groupby('ODS').mean()

for ods, row in datos_promedio_ods.iterrows():
    x = anios
    y = row[anios_c]
    plt.plot(x, y, color=colores_ods[ods], linewidth=3)
plt.xlabel('año')
plt.ylabel('nivel del indicador promedio')
plt.show()

# %%
# Hacemos un diagrama de barras a nivel ODS y graficamos la meta promedio
datos_promedio_ods = datos.groupby('ODS').mean()

for ods, row in datos_promedio_ods.iterrows():
    y = row[anios_c].mean()
    meta = row['Meta2030']
    plt.bar(ods, y, color=colores_ods[ods], linewidth=3)
    plt.plot(ods, meta, '.', mfc=colores_ods[ods], mec='w', markersize=25)
plt.xlabel('ODS')
plt.ylabel('nivel promedio')
plt.xticks(range(18))
plt.show()

# %% [markdown]
# ## Analizamos los datos presupuestales

# %%
datos_presu = pd.read_csv('https://raw.githubusercontent.com/oguerrer/IPP_Colombia/main/data/modeling/budget_target.csv')

# %%
# Imprimimos los datos presupuestales
datos_presu
# Out:
#    MetaODS           2000           2001           2002           2003  \
# 34      27.055466      24.570926      26.128113      25.007409      25.973999
# 35   11173.552880   10147.470436   10790.568340   10327.732529   10726.921337
# 36    1499.875030    1362.139481    1448.465335    1386.336853    1439.921718
# 37  103748.409883   94221.053353  100192.330858   95894.818699   99601.357208
# 38    2904.846076    2638.090140    2805.279613    2684.953804    2788.732974
# 39     509.399723     462.620859     491.939545     470.838966     489.037893
# 40    6026.332461    5472.926216    5819.773975    5570.148588    5785.446666
# 41   87912.086660   79839.001069   84898.813225   81257.280195   84398.046738
# 42    5714.885417    5190.079775    5519.002086    5282.277594    5486.448847
# 43  100059.009502   90870.455590   96629.388312   92484.700114   96059.430294
# 44   35782.772959   32496.792615   34556.283140   33074.073417   34352.456634
# 45     111.644446     101.391985     107.817722     103.193137     107.181771
# 46      27.836699      25.280417      26.882569      25.729505      26.724005
# 47     357.409185     324.587817     345.158633     330.353873     343.122752
# 48   12604.113370   11446.660625   12172.094959   11650.001844   12100.299171
# 49      11.631649      10.563499      11.232963      10.751151      11.166706
# 50    3614.748312    3282.801095    3490.849250    3341.117559    3470.258852
# 51     365.634730     332.057999     353.102239     337.956757     351.019504
# 52   67515.430274   61315.397173   65201.272344   62404.618565   64816.689676
#
#              2020
# 0    21572.191863
# 1    79850.702163
# 2   138338.897128
# 3    30578.394500
# 4    10066.674808
# 5     1270.733729
# 6    34244.863139
# 7     6503.636503
# 8     2794.888695
# 9     7939.759520
# 10  526443.671055
# 11     381.820441
# 12  396987.299035
# 13   64144.053089
# 14   78562.391185
# 15   50311.842847
# 16     217.644669
# 17    8644.802314
# 18    6080.931197
# 19      10.493575
# 20    2959.094041
# 21     571.361346
# 22   38561.941813
# 23    2904.648825
# 24    2397.402333
# 25     165.352405
# 26   36291.421739
# 27    8425.914376
# 28     592.706028
# 29    2917.771670
# 30    7904.176937
# 31     259.357968
# 32    5003.782627
# 33    6196.473582
# 34      28.941018
# 35   11952.261246
# 36    1604.404471
# 37  110978.854452
# 38    3107.290900
# 39     544.900859
# 40    6446.320226
# 41   94038.864605
# 42    6113.167784
# 43  107032.332011
# 44   38276.549554
# 45     119.425181
# 46      29.776697
# 47     382.317782
# 48   13482.520501
# 49      12.442283
# 50    3866.667713
# 51     391.116582
# 52   72220.722401
#
# [53 rows x 22 columns]

# %%
# graficamos el presupuesto obtenido del gasto nacional
datos_presu['ODS'] = [meta.split('.')[0] for meta in datos_presu.MetaODS]
datos_presu_ods = datos_presu.groupby('ODS').sum()
x = anios
y = datos_presu_ods[anios_c].values
colores = [colores_ods[int(c)] for c in datos_presu_ods.index]
plt.stackplot(x, y, colors=colores)
plt.xlabel('año')
plt.ylabel('millones de pesos reales')
plt.show()

# %%
# graficamos el presupuesto al interior de un ODS
datos_presu['ODS'] = [meta.split('.')[0] for meta in datos_presu.MetaODS]
datos_presu_edu = datos_presu[datos_presu.ODS == '4']
x = anios
y = datos_presu_edu[anios_c].values
plt.stackplot(x, y,)
plt.xlabel('año')
plt.ylabel('millones de pesos reales')
plt.show()
